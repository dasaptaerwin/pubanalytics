# %% [markdown]
# # a short analysis on scores

# %% [markdown]
# ## linear regression

# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.2     ✔ dplyr   0.7.4
# ✔ tidyr   0.8.0     ✔ stringr 1.3.0
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
d = read.csv('sinta_ts.csv')

# %%
head(d)
# Out:
#   no grup  name            affil sumdoc sumdoc2 sumcitation sumcitation2 hind
# 1 1  top10 suharyo s.      NA    661    635     35031       34799        86
# 2 2  top10 johannes v.d.w. NA    109    109      5716        5716        43
# 3 3  top10 suryadi i.      NA    152    142      4963        4955        32
# 4 4  top10 ferry i.        NA    180    131      3972        3866        31
# 5 5  top10 daniel m.       NA     79     59      4644        4123        30
# 6 6  top10 bachti a.       NA    111    101      2632        2531        26
#   hind2 sumcitation3 hind3
# 1 86    22082        64
# 2 43     3812        32
# 3 32     4577        30
# 4 31     2996        26
# 5 28     3639        25
# 6 26     2161        24

# %%
#calculate percentage of journals in sumdoc: sumdoc2/sumdoc -> sumdoc3
d$sumdoc3 = (d$sumdoc2/d$sumdoc)*100

# %%
head(d)
# Out:
#   no grup  name            affil sumdoc sumdoc2 sumcitation sumcitation2 hind
# 1 1  top10 suharyo s.      NA    661    635     35031       34799        86
# 2 2  top10 johannes v.d.w. NA    109    109      5716        5716        43
# 3 3  top10 suryadi i.      NA    152    142      4963        4955        32
# 4 4  top10 ferry i.        NA    180    131      3972        3866        31
# 5 5  top10 daniel m.       NA     79     59      4644        4123        30
# 6 6  top10 bachti a.       NA    111    101      2632        2531        26
#   hind2 sumcitation3 hind3 sumdoc3
# 1 86    22082        64     96.06657
# 2 43     3812        32    100.00000
# 3 32     4577        30     93.42105
# 4 31     2996        26     72.77778
# 5 28     3639        25     74.68354
# 6 26     2161        24     90.99099

# %%
#sort data based on sumdoc3 
arrange(d, desc(sumdoc3))
# Out:
#    no grup  name            affil sumdoc sumdoc2 sumcitation sumcitation2 hind
# 1   2 top10 johannes v.d.w. NA    109    109      5716        5716        43
# 2  32 top40 remy e.p.m.     NA     51     51       965         965        17
# 3   8 top10 effendy         NA     79     78      1959        1959        28
# 4  38 top40 i ketut adnyana NA     58     57       884         884        14
# 5  42 top50 rintis n.       NA     43     42       829         826        14
# 6  40 top40 raymond r.t.    NA     82     80      1062         979        18
# 7  28 top30 a.m. gunawan i. NA     94     91       846         836        15
# 8  27 top30 m. hakimi       NA     53     51      1190        1190        16
# 9   1 top10 suharyo s.      NA    661    635     35031       34799        86
# 10 46 top50 t. tedjo s.     NA     44     42      1531        1496        15
# 11 11 top20 moch. hatta     NA    131    125      1458        1417        22
# 12 13 top20 jamaluddin j.   NA     54     51      2091        2090        20
# 13 48 top50 evy y.          NA     54     51       717         707        14
# 14 14 top20 syafruddin      NA     97     91      1784        1773        22
# 15  3 top10 suryadi i.      NA    152    142      4963        4955        32
# 16 10 top10 ahmaf f.        NA     60     56      1531        1530        21
# 17 23 top30 euis h.h.       NA     60     56       953         941        18
# 18 19 top20 abdul r.        NA    133    123      1462        1421        21
# 19 45 top50 dondin s.       NA     50     46      1218        1182        12
# 20 33 top40 yana m.s.       NA     95     87      1001         986        17
# 21 37 top40 felycia e.s.    NA     67     61      1023        1021        14
# 22  6 top10 bachti a.       NA    111    101      2632        2531        26
# 23 15 top20 lesmana m.      NA     55     50      1093        1073        19
# 24 44 top50 togar m.s.      NA     55     50      1550        1550        12
# 25 36 top40 damayanti       NA     42     38      1379        1309        15
# 26  7 top10 biran a.        NA     71     64      1673        1609        25
# 27 18 top20 herawati s.     NA     64     57      1467        1395        21
# 28 54 top60 m. yasin        NA    104     92       488         479        12
# 29 16 top20 taniawati s.    NA     69     61      1278        1172        23
# 30 12 top20 danny h.n.      NA     51     45      2925        2868        26
# 31 29 top30 arridina s.s.   NA     41     36      2004        1982        17
# 32 58 top60 unang s.        NA     57     50       323         285         9
# 33 43 top50 dwi s.          NA     78     68       784         776        14
# 34 35 top40 iskandar m.     NA     57     48      1420        1225        23
# 35 50 top50 tole s.         NA    127    106       656         548        12
# 36 20 top20 jatna s.        NA     60     47      1220        1049        60
# 37  5 top10 daniel m.       NA     79     59      4644        4123        30
# 38 30 top30 terry m.        NA    116     86      1821        1798        20
# 39 17 top20 agustinus a.n.  NA    108     79      1695        1621        19
# 40  4 top10 ferry i.        NA    180    131      3972        3866        31
# 41 25 top30 heru s.         NA     60     40      1501        1481        15
# 42 22 top30 siti m.         NA    102     66      1164        1046        19
# 43 31 top40 ivandini t.a.   NA     56     33      1342        1148        19
# 44 51 top60 ig. wenten      NA     73     41       965         923        18
# 45 39 top40 nandy p.        NA     68     38      3727        3668        14
# 46 34 top40 rachmat h.      NA     88     49       844         793        15
# 47 21 top30 mikrajudin a.   NA    161     89      1392        1243        20
# 48 24 top30 sri w.          NA     81     44      3354        3295        17
# 49 52 top60 hadiyanto       NA     89     45       466         380        12
# 50 26 top30 asep b.d.n.     NA    124     62      1507        1439        20
# 51 49 top50 edy t.b.        NA    141     70       801         557        15
# 52 41 top50 hasanuddin z.a. NA     95     46      1123        1046        18
# 53 56 top60 jamari          NA    108     47       292         240        10
# 54 59 top60 mauridhi hp.    NA    227     95       584         319        11
# 55 60 top60 robbi r.        NA     97     39       927         307        19
# 56 55 top60 ansari sa.      NA     88     35       702         321        16
# 57 53 top60 khairurrijal    NA    194     70       714         510        12
# 58 47 top50 rosari s.       NA    132     39       886         664        14
# 59  9 top10 susanto r.      NA    326     91      3121        2072        27
# 60 57 top60 wisnu j.        NA    131     29       785         367        17
#    hind2 sumcitation3 hind3
# 1  43     3812        32
# 2  17      789        14
# 3  28     1419        22
# 4  14      771        13
# 5  14      557        12
# 6  17      793        12
# 7  15      706        15
# 8  16      994        15
# 9  86    22082        64
# 10 14     1109        11
# 11 22     1194        20
# 12 20     1853        19
# 13 14      461        11
# 14 22     1443        19
# 15 32     4577        30
# 16 21     1431        20
# 17 18      709        16
# 18 21      992        17
# 19 12     1015        11
# 20 17      729        14
# 21 14      934        13
# 22 26     2161        24
# 23 19      994        19
# 24 12     1496        11
# 25 14     1002        13
# 26 24     1254        23
# 27 20     1028        17
# 28 12      234         9
# 29 22      810        18
# 30 25     2158        20
# 31 17     1666        14
# 32  9      203         7
# 33 14      570        12
# 34 21      545        14
# 35 11      395        10
# 36 19      765        17
# 37 28     3639        25
# 38 20      962        14
# 39 19     1316        17
# 40 31     2996        26
# 41 15     1297        15
# 42 18      857        16
# 43 16      874        14
# 44 18      417         9
# 45 14     3515        12
# 46 15      581        14
# 47 20      928        16
# 48 17     2924        15
# 49 10      316         9
# 50 20     1047        15
# 51 15      300        11
# 52 18      772        12
# 53  9      157         8
# 54  9      195         7
# 55 10      125         7
# 56 12      197         9
# 57 12      299         8
# 58 13      521        11
# 59 24     1739        20
# 60 11      210         7

# %%
# Basic scatter plot
ggplot(d, aes(x=sumdoc, y=su
              mdoc3, color=grup)) + geom_point()
# Out:
# plot without title

# %%
# calculating correlation
m = lm(sumdoc ~ sumdoc3, data = d)
m
# Out:
# Call:
# lm(formula = sumdoc ~ sumdoc3, data = d)
#
# Coefficients:
# (Intercept)      sumdoc3
#    166.7761      -0.8362

# %%
# correlation matrix
install.packages('corrplot')

# %%
library('corrplot')

# %%
res = rcorr(d[,4:12])

# %%
corrplot(res, type = "upper", order = "hclust", 
         tl.col = "black", tl.srt = 45)
